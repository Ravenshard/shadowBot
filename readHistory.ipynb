# %%
import discord
import msgClass
import re, os, glob
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
path = "./log/Dominion (Card Game)/border-village"
for folder in os.listdir(path):
    dirs = glob.glob("{}/{}/*".format(path, folder))
    file = max(dirs)
    df = pd.read_csv(file, delimiter="\t")
    messagesSent = len(df["Content"])
    charCount = 0
    for x in df["Content"]: charCount += len(str(x))
    print("File: {}".format(folder))
    print("Messages: {}".format(messagesSent))
    print("Chars Sent: {}".format(charCount))
    print("Char per Message: {}\n".format(charCount/messagesSent))
# Out:
# File: Fircoal
# Messages: 172
# Chars Sent: 18857
# Char per Message: 109.63372093023256
#
# File: Will((ow)|(iam))
# Messages: 70
# Chars Sent: 6103
# Char per Message: 87.18571428571428
#
# File: DomBot
# Messages: 3
# Chars Sent: 99
# Char per Message: 33.0
#
# File: Donkey-Dude
# Messages: 19
# Chars Sent: 1666
# Char per Message: 87.6842105263158
#
# File: Jerry
# Messages: 94
# Chars Sent: 10569
# Char per Message: 112.43617021276596
#
# File: conjugate
# Messages: 445
# Chars Sent: 38827
# Char per Message: 87.25168539325843
#
# File: DDL
# Messages: 164
# Chars Sent: 11945
# Char per Message: 72.83536585365853
#
# File: Ravenshard
# Messages: 311
# Chars Sent: 19154
# Char per Message: 61.58842443729903
#
# File: mikaelsson
# Messages: 109
# Chars Sent: 9090
# Char per Message: 83.39449541284404
#
# File: Emmi
# Messages: 62
# Chars Sent: 6249
# Char per Message: 100.79032258064517
#
# File: pqr
# Messages: 157
# Chars Sent: 16470
# Char per Message: 104.90445859872611
#
# File: Anders
# Messages: 112
# Chars Sent: 10119
# Char per Message: 90.34821428571429
#
# File: bazkitcase5
# Messages: 74
# Chars Sent: 8207
# Char per Message: 110.9054054054054
#
# File: Bluey The Bear
# Messages: 44
# Chars Sent: 4903
# Char per Message: 111.43181818181819
#
# File: master
# Messages: 2867
# Chars Sent: 245747
# Char per Message: 85.71573072898501
#
# File: Rozyroz
# Messages: 15
# Chars Sent: 1089
# Char per Message: 72.6
#
# File: Caetra
# Messages: 256
# Chars Sent: 19102
# Char per Message: 74.6171875
#
# File: nottoobad
# Messages: 3
# Chars Sent: 182
# Char per Message: 60.666666666666664
#
# File: eh1414
# Messages: 98
# Chars Sent: 11309
# Char per Message: 115.39795918367346
#
# File: Sharur
# Messages: 659
# Chars Sent: 51807
# Char per Message: 78.61456752655539
